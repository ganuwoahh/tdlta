# %%
from ultralytics import YOLO

#modelv5 = YOLO("yolov5s.pt")
modelv11 = YOLO("yolo11s.pt")

#resultsv5 = modelv5("test1.mp4", save = True, show=True)
resultsv11 = modelv11("test1.mp4", save = True, show=True)
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:01<00:00, 14.1MB/s]
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/241) d:\code_stuff\ta_tdl\test1.mp4: 384x640 2 persons, 1 sports ball, 167.1ms
# video 1/1 (frame 2/241) d:\code_stuff\ta_tdl\test1.mp4: 384x640 2 persons, 1 sports ball, 146.5ms
# video 1/1 (frame 3/241) d:\code_stuff\ta_tdl\test1.mp4: 384x640 2 persons, 1 sports ball, 141.3ms
# ...
